# %% [markdown]
# # ML Assignment - 1
#
# Group 41 Team Members:
#
# 1. Hitesh Gupta  (2019AD040027)
# 2. Ankit Gupta (2019AD040026)
# 3. Aditya Mehta (2019AD04031)

# %%
# Importing Required Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Data Import

df = pd.read_csv("data_banknote_authentication.txt")

# %%
df.head()
# Out:
#     3.6216  8.6661  -2.8073  -0.44699  0
# 0  4.54590  8.1674  -2.4586  -1.46210  0
# 1  3.86600 -2.6383   1.9242   0.10645  0
# 2  3.45660  9.5228  -4.0112  -3.59440  0
# 3  0.32924 -4.4552   4.5718  -0.98880  0
# 4  4.36840  9.6718  -3.9606  -3.16250  0

# %%
# Columns

df.columns = ['Variance', 'Skewness', 'Curtosis', 'Entropy', 'Class']

# %%
df.head()
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   4.54590    8.1674   -2.4586 -1.46210      0
# 1   3.86600   -2.6383    1.9242  0.10645      0
# 2   3.45660    9.5228   -4.0112 -3.59440      0
# 3   0.32924   -4.4552    4.5718 -0.98880      0
# 4   4.36840    9.6718   -3.9606 -3.16250      0

# %%
df.describe()
# Out:
#           Variance     Skewness     Curtosis      Entropy        Class
# count  1371.000000  1371.000000  1371.000000  1371.000000  1371.000000
# mean      0.431410     1.917434     1.400694    -1.192200     0.444931
# std       2.842494     5.868359     4.310105     2.101683     0.497139
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.774700    -1.711300    -1.553350    -2.417000     0.000000
# 50%       0.495710     2.313400     0.616630    -0.586650     0.000000
# 75%       2.814650     6.813100     3.181600     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
# Check missing value counts in columns
df.isnull().sum()
# Out:
# Variance    0
# Skewness    0
# Curtosis    0
# Entropy     0
# Class       0
# dtype: int64

# %%
#separate variables into new data frames
numeric_data = df.select_dtypes(include=[np.number])
#correlation plot
corr = numeric_data.corr()
sns.heatmap(corr, square=True)

# %%
# Checking relationships between different feature columns
sns.pairplot(df,hue='Class');

# %%
# Count Plot of the classes

sns.countplot(data=df,x="Class")
plt.title('Classes Data Ditribution')
# Out:
# Text(0.5, 1.0, 'Classes Data Ditribution')
